# %%
import sys
import h5py
import argparse
import os
from context2vec.common.model_reader import ModelReader
import cupy as cp
from chainer import cuda

import numpy as np

import math
import re
from collections import defaultdict

# %%
def increment_write_h5py(hf,chunk,data_name='data'):
    if data_name not in hf:
        maxshape = (None,) + chunk.shape[1:]
        data=hf.create_dataset(data_name,data=chunk,chunks=chunk.shape,maxshape=maxshape,compression="gzip",compression_opts=9)

    else:
        data=hf[data_name]
        data.resize((chunk.shape[0]+data.shape[0],)+data.shape[1:])
        data[-chunk.shape[0]:]=chunk

# %%
class context2vec_batch_generator(object):
    
    def __init__(self,batchsize,model,word2index,output_f):
        self.same_len_dict=defaultdict(list)
        self.same_len_2_index=defaultdict(lambda:-1)
        self.batchsize=batchsize
        self.model=model
        self.word2index=word2index
        self.output_f=output_f
        
    def process_batch(self,w_lst):
        sent_len=len(w_lst)
        w_ind_lst=self.sent2wordid(w_lst)
        self.same_len_dict[sent_len].append(w_ind_lst)
        self.same_len_2_index[sent_len]+=1
        if len(self.same_len_dict[sent_len])>=self.batchsize: #process batches
            #run model for a batch
            print ('run model for sent len {0}'.format(str(sent_len)))
            self.model.reset_state()
            sent_ys = self.model._contexts_rep(xp.array(self.same_len_dict[sent_len]))
            sent_ys=xp.array([arr.data for arr in sent_ys]).swapaxes(0,1)
            #write to h5py
            increment_write_h5py(self.output_f,sent_ys,data_name=str(len(w_lst)))
            self.same_len_dict[sent_len]=[]
    
    def process_remainder(self):
        for sent_len in self.same_len_dict:
            if self.same_len_dict[sent_len]!=[]:
                print ('remainder run_model for sent leng {0}'.format(str(sent_len)))
                self.model.reset_state()
                sent_ys = self.model._contexts_rep(xp.array(self.same_len_dict[sent_len]))
                sent_ys=xp.array([arr.data for arr in sent_ys]).swapaxes(0,1)
                #write to h5py
                increment_write_h5py(self.output_f,sent_ys,data_name=str(sent_len))
                self.same_len_dict[sent_len]=[]
                
    #helper functions
    def sent2wordid(self,w_lst):
        sent_inds = []
        for word in w_lst:
            word= word.decode('utf-8')
            if word in self.word2index:
                ind = self.word2index[word]
            else:
                print ('unknown word: {0}'.format(word.encode('utf-8')))
                ind = self.word2index['<UNK>']
            sent_inds.append(ind)
        return sent_inds

# %%
if __name__ == '__main__':
    
    
    
    if sys.argv[0]=='/usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py':
        model_param_file='../models/context2vec/model_dir/MODEL-wiki.params.14'
        gpu=-1
        text_f='eval_data/CRW/context'
        batchsize=100

    else:
        parser = argparse.ArgumentParser(description='Write context2vec embeddings to file.')
        parser.add_argument('--f',  type=str,
                            help='model_param_file',dest='model_param_file')
        parser.add_argument('--g', dest='gpu',type=int, default=-1,help='gpu, default is -1')
        parser.add_argument('--t', dest='text_f', type=str, help='data text file or folder')
        parser.add_argument('--b',dest='batchsize',type=int,help='batch size')
        args = parser.parse_args()
        model_param_file=args.model_param_file
        text_f=args.text_f
        gpu=args.gpu
        batchsize=args.batchsize

    #1.setup
    if gpu >= 0:
            cuda.check_cuda_available()
            cuda.get_device(gpu).use()    
    xp = cuda.cupy if gpu >= 0 else np
    
    #2. initialize context2vec model 
    model_reader = ModelReader(model_param_file,gpu)
    word2index=model_reader.word2index
    model = model_reader.model
# Out:
# Reading config file: ../models/context2vec/model_dir/MODEL-wiki.params.14
# Config:  {'config_path': '../models/context2vec/model_dir/', 'model_file': 'MODEL-wiki.14', 'deep': 'yes', 'drop_ratio': '0.0', 'words_file': 'WORDS-wiki.targets.14', 'unit': '400'}

# %%
    #3. process context2vec text into vectors and store in h5py
    output_f = h5py.File(text_f+'_'+model_param_file.split('/')[-1]+'.'+'vec.h5', 'w')
    bg=context2vec_batch_generator(batchsize,model,word2index,output_f)
    index_out_f=open(text_f+'_'+model_param_file.split('/')[-1]+'.'+'index','w')

    if os.path.isdir(text_f):
        index_out=defaultdict(list)
        for root, subdir, files in os.walk(text_f):
            for f in files:
                name=f.split('.')[0]
                for line in open(os.path.join(root,f)):
                    #read in one line at once and batch sentences
                    w_lst=line.strip().split()
                    bg.process_batch(w_lst) # process batch and write to h5py          
                    index_in_h5py=bg.same_len_2_index[len(w_lst)]
                    index_out[name].append(str(len(w_lst))+','+str(index_in_h5py))         
        bg.process_remainder()
                
        #write indexes
        for name in index_out:
            index_out_f.write('{0}:::{1}\n'.format(name,'\t'.join(index_out[name])))
    
    index_out_f.close()
    output_f.close()
# Out:
# unknown word: trimetalisium
# unknown word: beta-7
# unknown word: 봉수호
# unknown word: 349-foot
# unknown word: 3743-tonne
# unknown word: randolph"s
# unknown word: kandelfels
# unknown word: uboat.net
# unknown word: ub-36
# unknown word: molière
# unknown word: 00424
# unknown word: 197-foot
# unknown word: finncarriers
# unknown word: —
# unknown word: exhange
# unknown word: 338,000
# unknown word: sc-7
# unknown word: kinai
# unknown word: 8360
# unknown word: shosen
# unknown word: a.b.y.
# unknown word: awarru
# unknown word: tark
# unknown word: yt-1300
# unknown word: ’s
# unknown word: shiriya
# unknown word: shoyo
# unknown word: 20,660
# unknown word: bccs
# unknown word: u-862
# unknown word: ilissos
# unknown word: 7131-ton
# unknown word: corinaldo
# unknown word: u-509
# unknown word: u-659
# unknown word: u-203
# unknown word: afric
# unknown word: 5,273-ton
# unknown word: eurolychus
# unknown word: sa226
# unknown word: jetcraft
# unknown word: wdio
# unknown word: 11,063
# unknown word: 1:42am
# unknown word: iburi
# unknown word: taibun
# unknown word: 1938/39
# unknown word: —
# unknown word: —
# unknown word: elna
# unknown word: unsalvageable
# unknown word: 747x
# unknown word: 747x
# unknown word: 6,854-ton
# unknown word: alfhem
# unknown word: rocc
# unknown word: federlock
# unknown word: hakusan
# unknown word: 5,600-ton
# unknown word: 7142
# unknown word: gsg-9
# unknown word: penaco
# unknown word: hardberger
# unknown word: 2000-tonne
# unknown word: anzoategui
# unknown word: aifv
# unknown word: katsuragsan
# unknown word: 葛城山丸
# unknown word: 2,428
# unknown word: saishu
# unknown word: gp7200
# unknown word: ryujin
# unknown word: ws.19
# unknown word: woniora
# unknown word: jolles
# unknown word: fs-318
# unknown word: cardig
# unknown word: tellarite
# unknown word: yapalaga
# unknown word: atule
# unknown word: 3,080-ton
# unknown word: tamahime
# unknown word: 7,006-ton
# unknown word: takoka
# unknown word: christoper
# unknown word: sr.n4
# unknown word: carvair
# unknown word: 5,425-ton
# unknown word: 1961/2
# unknown word: berwind
# unknown word: wakiva
# unknown word: gumprich
# unknown word: wellpark
# unknown word: tatsunan
# unknown word: kisen
# unknown word: 13sep08
# unknown word: antalina
# unknown word: grayback
# unknown word: marus
# unknown word: subchaser
# unknown word: sc-195
# unknown word: mayagüez
# unknown word: 8416
# unknown word: shosen
# unknown word: lanser
# unknown word: lanser
# unknown word: 3,743-strong
# unknown word: mǣrsk
# unknown word: maskargo
# unknown word: 200f
# unknown word: 400f
# unknown word: maswings
# unknown word: ikutagawa
# unknown word: sappa
# unknown word: 1930/31
# unknown word: kurmark
# unknown word: wauf
# unknown word: messis
# unknown word: 第２日野丸
# unknown word: ap-64
# unknown word: 40,000-mile
# unknown word: upbound
# unknown word: galerna
# unknown word: topdalsfjord
# unknown word: cartiercliffe
# unknown word: 205-ton
# unknown word: padmé
# unknown word: chudnovsky
# unknown word: ziyal
# unknown word: 1/2-inch
# unknown word: 8,022-ton
# unknown word: paracels
# unknown word: 6/10/03
# unknown word: 6/10/2103
# unknown word: 2092
# unknown word: instone
# unknown word: hawkair
# unknown word: 星光丸
# unknown word: u-230
# unknown word: 2868-ton
# unknown word: 41-man
# unknown word: shinwa
# unknown word: wind'n
# unknown word: …
# unknown word: …
# unknown word: hiob
# unknown word: finnpulp
# unknown word: peac
# unknown word: ’s
# unknown word: b727
# unknown word: rpc-5353
# unknown word: ix-196
# unknown word: tecklenborg
# unknown word: geestemünde
# unknown word: pungo
# unknown word: afrikanische
# unknown word: fruchtkompanie
# unknown word: laeisz
# unknown word: 400erf
# unknown word: 4-engined
# unknown word: airlifter
# unknown word: 600f
# unknown word: 600f.
# unknown word: nekton
# unknown word: granius
# unknown word: illuminative
# unknown word: заголовок
# unknown word: ’s
# unknown word: dwork
# unknown word: ’s
# unknown word: ‘
# unknown word: znaczy
# unknown word: kapitan’describes
# unknown word: posteriors
# unknown word: –
# unknown word: ’s
# unknown word: ’s
# unknown word: nibbána
# unknown word: introspections
# unknown word: 1996–98
# unknown word: laurino
# unknown word: laurino
# unknown word: tlvs
# unknown word: 15th-18th
# unknown word: goodfriend
# unknown word: goodfriend
# unknown word: grabe
# unknown word: lnsaaf
# unknown word: bayaan
# unknown word: sahoobul
# unknown word: ikhtilaf
# unknown word: “
# unknown word: ”
# unknown word: canalise
# unknown word: rafto
# unknown word: popjneo
# unknown word: trentabank
# unknown word: 44’0
# unknown word: 24’0
# unknown word: “
# unknown word: ”
# unknown word: “
# unknown word: ”
# unknown word: graczak
# unknown word: fitrec
# unknown word: gutkind
# unknown word: ’s
# unknown word: ~30%
# unknown word: kostheim
# unknown word: exergue
# unknown word: biesty
# unknown word: ~30%
# unknown word: introspections
# unknown word: islamska
# unknown word: vjerska
# unknown word: zajednica
# unknown word: “
# unknown word: ”
# unknown word: calt
# unknown word: synaesthetes
# unknown word: dasornis
# unknown word: odontopteryx
# unknown word: symplesiomorphy
# unknown word: pelagornis
# unknown word: —
# unknown word: iub
# unknown word: newsfeed
# unknown word: vyv
# unknown word: “
# unknown word: ”
# unknown word: salaat
# unknown word: jummah
# unknown word: sagdeev
# unknown word: cm³
# unknown word: cytologic
# unknown word: chartjunk
# unknown word: “
# unknown word: –
# unknown word: avuncular
# unknown word: xas
# unknown word: exafs
# unknown word: kossel
# unknown word: bordwehr
# unknown word: …
# unknown word: –
# unknown word: darwinius
# unknown word: anthropoids
# unknown word: adapiforms
# unknown word: craft&design
# unknown word: –
# unknown word: ’s
# unknown word: plumbline
# unknown word: megascops
# unknown word: ltbs
# unknown word: ’re
# unknown word: lifeguarded
# unknown word: educause
# unknown word: vodcasts
# unknown word: techies
# unknown word: copeia
# unknown word: françois
# unknown word: émile
# unknown word: ’s
# unknown word: —
# unknown word: wwii"and
# unknown word: crimtrac
# unknown word: crimtrac
# unknown word: jaam
# unknown word: 96,1
# unknown word: stationarity
# unknown word: spokeman
# unknown word: zhitro
# unknown word: chöd
# unknown word: sutric
# unknown word: shreedhar
# unknown word: chikitsak
# unknown word: distilles
# unknown word: aopa
# unknown word: “
# unknown word: ”
# unknown word: ph.d.
# unknown word: p309
# unknown word: —
# unknown word: —
# unknown word: 22.:45
# unknown word: boyishly
# unknown word: braying
# unknown word: brad,56,is
# unknown word: bra,34c-42d
# unknown word: big&rich
# unknown word: and,"save
# unknown word: brad!!!!"one
# unknown word: kachess
# unknown word: zamaneh
# unknown word: ullas
# unknown word: visualdna
# unknown word: visualiser
# unknown word: ’s
# unknown word: “
# unknown word: ”
# unknown word: bccie
# unknown word: 53.3±2.8%
# unknown word: 29.1±2.3%
# unknown word: 17.6±2.4%
# unknown word: freesco
# unknown word: placeplace
# unknown word: ‘
# unknown word: cambridge’.
# unknown word: cfel
# unknown word: cutec
# unknown word: 12.1%
# unknown word: 37.5%
# unknown word: 4.2%
# unknown word: 3.2%
# unknown word: kremmling
# unknown word: 9–6–3
# unknown word: uruks
# unknown word: ambushers
# unknown word: hammerhand
# unknown word: dunlendings
# unknown word: riffness
# unknown word: morrisound
# unknown word: …
# unknown word: metoyer
# unknown word: makgona
# unknown word: tsohle
# unknown word: mangxola
# unknown word: kffa
# unknown word: outboards
# unknown word: 86–68
# unknown word: elysabeth
# unknown word: .689
# unknown word: nicholaw
# unknown word: bearg
# unknown word: ub-46
# unknown word: kapitänleutnant
# unknown word: telchar
# unknown word: nogrod
# unknown word: dioscoro
# unknown word: umali
# unknown word: upca
# unknown word: pentavarit
# unknown word: bronleewe
# unknown word: moak
# unknown word: andyhunt
# unknown word: nickleback
# unknown word: pathaan
# unknown word: skylstad
# unknown word: shim'tar
# unknown word: hipoltya
# unknown word: nu'bia
# unknown word: göran
# unknown word: depature
# unknown word: illka
# unknown word: ’ve
# unknown word: —
# unknown word: ueo
# unknown word: papadopulo
# unknown word: brocas
# unknown word: l'endehors
# unknown word: jarach
# unknown word: mignard
# unknown word: lodé
# unknown word: sakolsky
# unknown word: batucada
# unknown word: walky
# unknown word: jigzag
# unknown word: fibby
# unknown word: sunchaser
# unknown word: bluffhearts
# unknown word: ramuglia
# unknown word: humlehjertene
# unknown word: vendt
# unknown word: “
# unknown word: ”
# unknown word: “
# unknown word: ”
# unknown word: sharpley
# unknown word: sindivários
# unknown word: fosp
# unknown word: federação
# unknown word: operária
# unknown word: são
# unknown word: forgs
# unknown word: federação
# unknown word: operária
# unknown word: jarach
# unknown word: –
# unknown word: ravachol
# unknown word: communard
# unknown word: almereyda
# unknown word: eugène
# unknown word: vallecas
# unknown word: 1985–1992
# unknown word: galaction
# unknown word: auner
# unknown word: panait
# unknown word: muşoiu
# unknown word: pieing
# unknown word: cairoli
# unknown word: güney
# unknown word: confederacion
# unknown word: veretz
# unknown word: cenetry
# unknown word: bizeau
# unknown word: coyurrier
# unknown word: www.silentsf.com
# unknown word: dolgoff
# unknown word: 1809–1865
# unknown word: brylcreem
# unknown word: eurodusnie
# unknown word: 3cr
# unknown word: cbaa
# unknown word: unreconstructed
# unknown word: …
# unknown word: ottesen
# unknown word: ottar
# unknown word: −
# unknown word: ”
# unknown word: mühsam
# unknown word: 1981/2
# unknown word: iberico
# unknown word: 1982/3/4
# unknown word: rakhel
# unknown word: peisoty
# unknown word: derazhnia
# unknown word: pesotta
# unknown word: norodnaya
# unknown word: shinri
# unknown word: haba
# unknown word: mett
# unknown word: ‘
# unknown word: west’
# unknown word: déjacque
# unknown word: capoliveri
# unknown word: argenti
# unknown word: volontà
# unknown word: infoshop.org
# unknown word: graswurzelrevolution
# unknown word: stelton
# unknown word: lucía
# unknown word: sánchez
# unknown word: saornil
# unknown word: –
# unknown word: fraternize
# unknown word: bookfair
# unknown word: ülo
# unknown word: voitka
# unknown word: bandwagoner
# unknown word: georgakas
# unknown word: libertatia
# unknown word: illegalism
# unknown word: witcop
# unknown word: frumkin
# unknown word: arbeter
# unknown word: fraynd
# unknown word: tschek
# unknown word: eigene
# unknown word: ’s
# unknown word: caricaturing
# unknown word: feldhirsch
# unknown word: kemerton
# unknown word: black–
# unknown word: anarchy–
# unknown word: grubacic
# unknown word: powelton
# unknown word: bellegarrigue
# unknown word: l'anarchie
# unknown word: notoc__clifford
# unknown word: minarchists
# unknown word: federación
# unknown word: anarquista
# unknown word: ibérica
# unknown word: santillán
# unknown word: são
# unknown word: agadoo
# unknown word: bertaut
# unknown word: d'axa
# unknown word: bucquoy
# unknown word: macedonio
# unknown word: vedia
# unknown word: élisée
# unknown word: reclus
# unknown word: orthodoxies
# unknown word: phoo
# unknown word: freebies
# unknown word: 의열단
# unknown word: speciesist
# unknown word: zeisler
# unknown word: libertaire
# unknown word: “
# unknown word: luxemburgism
# unknown word: —
# unknown word: —
# unknown word: anarkistens
# unknown word: svigermoder
# unknown word: “
# unknown word: café
# unknown word: ”
# unknown word: ‘
# unknown word: …
# unknown word: returning.’
# unknown word: pappe
# unknown word: chanteau
# unknown word: namri
# unknown word: songtsen
# unknown word: songtsän
# unknown word: frothing
# unknown word: doukoku
# unknown word: shitari
# unknown word: μg
# unknown word: μg
# unknown word: maybrick
# unknown word: 62,562
# unknown word: 80%
# unknown word: 19,250
# unknown word: exposé
# unknown word: ergotism
# unknown word: claviceps
# unknown word: ergoline
# unknown word: sodam
# unknown word: reflexa
# unknown word: hemostatic
# unknown word: hexaflouride
# unknown word: rollini
# unknown word: rollini
# unknown word: virosa
# unknown word: phalloides
# unknown word: stramonium
# unknown word: akelarre
# unknown word: ponticum
# unknown word: sumdac
# unknown word: chloracne
# unknown word: daxamite
# unknown word: budington
# unknown word: bessels
# unknown word: porzia
# unknown word: mururoa
# unknown word: micobes
# unknown word: władysław
# unknown word: karenga
# unknown word: maafa
# unknown word: 100%
# unknown word: 100/7
# unknown word: ergotism
# unknown word: khorloogiin
# unknown word: peljidiin
# unknown word: genden
# unknown word: anandyn
# unknown word: demid
# unknown word: invalidism
# unknown word: antiemetics
# unknown word: vasopressors
# unknown word: darvocet
# unknown word: dextropropoxyphene
# unknown word: sedre
# unknown word: cicuta
# unknown word: outage./
# unknown word: chapulin
# unknown word: angangueo
# unknown word: zitácuaro
# unknown word: hakamada
# unknown word: megimide
# unknown word: daptazole
# unknown word: phalloides
# unknown word: silybin
# unknown word: basilashvili
# unknown word: shakhnazarov
# unknown word: ’s
# unknown word: yady
# unknown word: vsemirnaya
# unknown word: istoriya
# unknown word: otravleniy
# unknown word: digoxine
# unknown word: rené
# unknown word: pottersville
# unknown word: carbofuran
# unknown word: weedkiller
# unknown word: farmland.[1
# unknown word: hopis
# unknown word: choka
# unknown word: muscave
# unknown word: zonama
# unknown word: sekot
# unknown word: zonama
# unknown word: sekot
# unknown word: myristicin
# unknown word: mitigations
# unknown word: holddown
# unknown word: harangues
# unknown word: bottweill
# unknown word: autumnalis
# unknown word: giuyu
# unknown word: sensorites
# unknown word: blystone
# unknown word: antiinflammatory
# unknown word: quinquangulata
# unknown word: siamea
# unknown word: barakol
# unknown word: aconitine
# unknown word: diethylstilbestrol
# unknown word: phocomelia
# unknown word: minimata
# unknown word: tierkel
# unknown word: ’s
# unknown word: “
# unknown word: shanaar
# unknown word: slaanesh
# unknown word: shanaar
# unknown word: delko
# unknown word: —
# unknown word: —
# unknown word: daxamite
# unknown word: gouhourou
# unknown word: horsts
# unknown word: benedendorpsweg
# unknown word: r.c.t.
# unknown word: pendelton
# unknown word: currahees
# unknown word: telthus
# unknown word: folkemuseum
# unknown word: –
# unknown word: wo1
# unknown word: champeny
# unknown word: popilius
# unknown word: battalion/442nd
# unknown word: shian
# unknown word: fovant
# unknown word: 3-pounders
# unknown word: fouché
# unknown word: vystrel
# unknown word: lcol
# unknown word: headaquarters
# unknown word: 542nd
# unknown word: guánica
# unknown word: h+195
# unknown word: rct-1
# unknown word: —
# unknown word: ravc
# unknown word: 772d
# unknown word: 747th
# unknown word: 491st
# unknown word: lcm-468
# unknown word: lemery
# unknown word: propodosoma
# unknown word: unguiculatus
# unknown word: jird
# unknown word: gerbillinae
# unknown word: onthophagini
# unknown word: dynastinae
# unknown word: cryptocephalinae
# unknown word: loricariichthys
# unknown word: loricariinae
# unknown word: furcodontichthys
# unknown word: hemiodontichthys
# unknown word: limatulichthys
# unknown word: pseudoloricaria
# unknown word: canistrum
# unknown word: bromelioideae
# unknown word: diplodocidae
# unknown word: dicraeosaurinae
# unknown word: dicraeosaurus
# unknown word: pipistrellus
# unknown word: vespertilioninae
# unknown word: abolla
# unknown word: ophiderinae
# unknown word: calpinae
# unknown word: avicularia
# unknown word: iridopelma
# unknown word: pachistopelma
# unknown word: aviculariinae
# unknown word: calyptorhynchus
# unknown word: lathami
# unknown word: calyptorhynchinae
# unknown word: egogepa
# unknown word: tortricinae
# unknown word: gymnostachys
# unknown word: protoaroids
# unknown word: atracotoxins
# unknown word: actx
# unknown word: atracinae
# unknown word: orsodacnidae
# unknown word: hylinae
# unknown word: kerivoula
# unknown word: kerivoulinae
# unknown word: coliadinae
# unknown word: sulfurs
# unknown word: trpc3
# unknown word: cnemiornis
# unknown word: anserinae
# unknown word: lutjanidae
# unknown word: lutjanus
# unknown word: lutjaninae
# unknown word: archaeospheniscus
# unknown word: palaeeudyptinae
# unknown word: arvicolinae
# unknown word: maxillaridae
# unknown word: vandeae
# unknown word: isolabiinae
# unknown word: africolabis
# unknown word: geracodes
# unknown word: isolabis
# unknown word: pterolabis
# unknown word: eumeninae
# unknown word: vespidae
# unknown word: lemurinae
# unknown word: hapalemur
# unknown word: lemuridae
# unknown word: loricariinae
# unknown word: penelopinae
# unknown word: oreophasis
# unknown word: derbianus
# unknown word: cracid
# unknown word: pareronia
# unknown word: pierinae
# unknown word: tupian
# unknown word: murinae
# unknown word: corticivora
# unknown word: olethreutinae
# unknown word: eligminae
# unknown word: dipodomyinae
# unknown word: dnaj
# unknown word: hsp40
# unknown word: dnajc13
# unknown word: hnf4
# unknown word: nr2a2
# unknown word: arinae
# unknown word: conures
# unknown word: k+-atpases
# unknown word: donatia
# unknown word: monogeneric
# unknown word: donatioideae
# unknown word: chrysallidinae
# unknown word: odostomiidae
# unknown word: colobinae
# unknown word: rosoideae
# unknown word: abietoideae
# unknown word: abietaceae
# unknown word: zapater
# unknown word: erebia
# unknown word: zapateri
# unknown word: arecoideae
# unknown word: roystoneae
# unknown word: homalomitrinae
# unknown word: roháček
# unknown word: isolabiinae
# unknown word: ig)-like
# unknown word: egf)-like
# unknown word: rtks
# unknown word: pachylinae
# unknown word: sørensen
# unknown word: gonyleptidae
# unknown word: kury
# unknown word: peiratinae
# unknown word: reduviidae
# unknown word: cyp51a1
# unknown word: lanosterol
# unknown word: demethylase
# unknown word: p45014dm
# unknown word: lanosterol
# unknown word: aveneae
# unknown word: pooideae
# unknown word: triticeae
# unknown word: trpm5
# unknown word: eurochelidon
# unknown word: leucocarboninae
# unknown word: euploea
# unknown word: mimosoideae
# unknown word: semnornithidae
# unknown word: ramphastidae
# unknown word: semnornithinae
# unknown word: jasonia
# unknown word: phthiria
# unknown word: relativitae
# unknown word: bombyliidae
# unknown word: phthiriinae
# unknown word: ratardinae
# unknown word: spheniscinae
# unknown word: lithosiinae
# unknown word: rhopaltriplasia
# unknown word: olethreutinae
# unknown word: mexipedium
# unknown word: phragmipedium
# unknown word: selenipedium
# unknown word: cypripedioideae
# unknown word: lady's
# unknown word: arecoideae
# unknown word: halothamnus
# unknown word: salsoloideae
# unknown word: chenopodiaceae
# unknown word: herpestidae
# unknown word: eupleridae
# unknown word: crocidurinae
# unknown word: sigmodontinae
# unknown word: deermice
# unknown word: sigmodontinae
# unknown word: collicularia
# unknown word: olethreutinae
# unknown word: rasborinae
# unknown word: –
# unknown word: rasborines
# unknown word: amycinae
# unknown word: scyllarides
# unknown word: arctidinae
# unknown word: multiarticulated
# unknown word: exopods
# unknown word: maxillipeds
# unknown word: palp
# unknown word: vanilloideae
# unknown word: monandrous
# unknown word: bovinae
# unknown word: colubrinae
# unknown word: bagauda
# unknown word: zetteli
# unknown word: emesinae
# unknown word: philosininae
# unknown word: megapodagrionidae
# unknown word: morphinae
# unknown word: hatchetfishes
# unknown word: sternoptychinae
# unknown word: adapis
# unknown word: adapidae
# unknown word: adapinae
# unknown word: heterorrhina
# unknown word: brachycrus
# unknown word: merycoidodontidae
# unknown word: merycochoerinae
# unknown word: oreodont
# unknown word: subepochs
# unknown word: 20.6—13.6
# unknown word: euagoras
# unknown word: reduviidae
# unknown word: harpactorinae
# unknown word: pyraustinae
# unknown word: spilomelini
# unknown word: crambinae
# unknown word: ablabesmyia
# unknown word: tanypodinae
# unknown word: bloodworm
# unknown word: schoenig
# unknown word: parantica
# unknown word: schoenigi
# unknown word: leeuwenhoekiidae
# unknown word: submedian
# unknown word: velociraptorinae
# unknown word: barsbold
# unknown word: hitleri
# unknown word: cyp27c1
# unknown word: cyp27c1
# unknown word: hiroshiinoueana
# unknown word: olethreutinae
# unknown word: anserinae
# unknown word: maurolicinae
# unknown word: xerinae
# unknown word: anatinae
# unknown word: rivulines
# unknown word: aplocheilidae
# unknown word: xiphorhynchus
# unknown word: erythropygius
# unknown word: dendrocolaptinae
# unknown word: anthiinae
# unknown word: anthias
# unknown word: trachyphoninae
# unknown word: heterotetramers
# unknown word: kir2.1
# unknown word: kir2.3
# unknown word: kcnj8
# unknown word: kir6.1
# unknown word: leucaena
# unknown word: mimosoideae
# unknown word: coninae
# unknown word: labeoninae
# unknown word: labeonini
# unknown word: cyprininae
# unknown word: pseudeboda
# unknown word: tortricinae
# unknown word: bulimulinae
# unknown word: bulimulidae
# unknown word: dactylioglypha
# unknown word: olethreutinae
# unknown word: cichorioideae
# unknown word: malvoideae
# unknown word: tc1/mariner
# unknown word: “
# unknown word: acanthopelminae
# unknown word: cuterebrinae
# unknown word: oestridae
# unknown word: oestridae
# unknown word: galidiinae
# unknown word: caralluma
# unknown word: burchardii
# unknown word: caralluma
# unknown word: asclepiadoideae
# unknown word: gcnf
# unknown word: nyctomyini
# unknown word: tylomyinae
# unknown word: nyctomys
# unknown word: otonyctomys
# unknown word: dicellitis
# unknown word: tortricinae
# unknown word: adenoneura
# unknown word: olethreutinae
# unknown word: gabaс
# unknown word: ρ
# unknown word: gabaс
# unknown word: iuphar
# unknown word: gabaс
# unknown word: ρ
# unknown word: ρ
# unknown word: gabaa-ρ
# unknown word: periphoeba
# unknown word: olethreutinae
# unknown word: pyrginae
# unknown word: celaenorrhini
# unknown word: deinacanthon
# unknown word: bromelioideae
# unknown word: ratufa
# unknown word: ratufinae
# unknown word: suleima
# unknown word: olethreutinae
# unknown word: palmarum
# unknown word: dransfield
# unknown word: zombia
# unknown word: coryphoideae
# unknown word: corypheae
# unknown word: thrinacinae
# unknown word: avaria
# unknown word: tortricinae
# unknown word: astatochroa
# unknown word: drepaninae
# unknown word: eriopterinae
# unknown word: nadata
# unknown word: gibbosa
# unknown word: busyconinae
# unknown word: busycon
# unknown word: kcng3
# unknown word: glandulocaudinae
# unknown word: rhacophorinae
# unknown word: xiphocolaptes
# unknown word: promeropirhynchus
# unknown word: dendrocolaptinae
# unknown word: callichthys
# unknown word: callichthyinae
# unknown word: gossweilerodendron
# unknown word: xerorchis
# unknown word: xeros
# unknown word: epidendroideae
# unknown word: xerorchideae
# unknown word: phlaeothripinae
# unknown word: macroramphosinae
# unknown word: macroramphosidae
# unknown word: desmodontidae
# unknown word: desmodontinae
# unknown word: allodapella
# unknown word: olethreutinae
# unknown word: salpornis
# unknown word: spilonotus
# unknown word: salpornithinae
# unknown word: tanychaeta
# unknown word: tortricinae
# unknown word: deirochelyinae
# unknown word: emydidae
# unknown word: australopithecinae
# unknown word: curtus
# unknown word: bulimulinae
# unknown word: cercyonis
# unknown word: pegala
# unknown word: microraptoria
# unknown word: macropodinae
# unknown word: macropodidae
# unknown word: dasyhelea
# unknown word: dasyheleinae
# unknown word: oryzomyalia
# unknown word: sigmodontinae
# unknown word: varicellovirus
# unknown word: alphaherpesvirinae
# unknown word: cebus
# unknown word: capucinus
# unknown word: cebidae
# unknown word: cebinae
# unknown word: parantica
# unknown word: kirbyi
# unknown word: apapane
# unknown word: himatione
# unknown word: drepanidinae
# unknown word: monarchinae
# unknown word: dicruridae
# unknown word: eremoblatta
# unknown word: polyphaginae
# unknown word: polyphagidae
# unknown word: trilophosuchus
# unknown word: mekosuchinae
# unknown word: neophemini
# unknown word: neophema
# unknown word: neopsephotus
# unknown word: platycercinae
# unknown word: pyrginae
# unknown word: neogastropoda
# unknown word: swi
# unknown word: smarcd2
# unknown word: smittia
# unknown word: orthocladiinae
# unknown word: bloodworm
# unknown word: xerocnephasia
# unknown word: tortricinae
# unknown word: selenipedium
# unknown word: cypripedioideae
# unknown word: baryonyx
# unknown word: aegyptiacus
# unknown word: harmologa
# unknown word: tortricinae
# unknown word: biologies
# unknown word: hymenolaimus
# unknown word: tadorninae
# unknown word: ectrichodiinae
# unknown word: reduviid
# unknown word: xenochironomus
# unknown word: chironominae
# unknown word: bloodworm
# unknown word: lutung
# unknown word: trachypithecus
# unknown word: lutung
# unknown word: colobinae
# unknown word: cyclocoelinae
# unknown word: echinostomida
# unknown word: trichopezinae
# unknown word: empidoid
# unknown word: schizanthus
# unknown word: schizanthoideae
# unknown word: desmans
# unknown word: talpidae
# unknown word: talpinae
# unknown word: harsiesis
# unknown word: plusiini
# unknown word: plusiinae
# unknown word: beardius
# unknown word: chironominae
# unknown word: bloodworm
# unknown word: elymniini
# unknown word: monographical
# unknown word: pogonodon
# unknown word: nimravidae
# unknown word: nimravinae
# unknown word: 30.8—7.2
# unknown word: mokilese
# unknown word: mwoakilloan
# unknown word: ponapeic
# unknown word: trukic
# unknown word: stictea
# unknown word: olethreutinae
# unknown word: eubrochoneura
# unknown word: olethreutinae
# unknown word: acropolitis
# unknown word: tortricinae
# unknown word: pseudochelidon
# unknown word: sirintarae
# unknown word: anthias
# unknown word: basslets
# unknown word: anthiinae
# unknown word: ehv-2
# unknown word: gammaherpesvirinae
# unknown word: rhadinovirus
# unknown word: taoniinae
# unknown word: duckbills
# unknown word: cheneosaurinae
# unknown word: arctiinae
# unknown word: opifex
# unknown word: phidippus
# unknown word: opifex
# unknown word: viperines
# unknown word: crotalines
# unknown word: viperidae
# unknown word: ecitoninae
# unknown word: weygoldt
# unknown word: hypoctonidae
# unknown word: hypoctonidae
# unknown word: macropodidae
# unknown word: lagostrophus
# unknown word: sthenurinae
# unknown word: erynnini
# unknown word: pyrginae
# unknown word: amorpha
# unknown word: pseudaechmea
# unknown word: bromelioideae
# unknown word: erebia
# unknown word: apinae
# unknown word: euploea
# unknown word: andamanensis
# unknown word: yinlong
# unknown word: shishugou
# unknown word: martray
# unknown word: martray
# unknown word: côte
# unknown word: impressive.307
# unknown word: mirum
# unknown word: lacrymosa
# unknown word: fallom
# unknown word: fallom
# unknown word: lisesi
# unknown word: 87%
# unknown word: crowdpleasing
# unknown word: tannerite
# unknown word: —
# unknown word: —
# unknown word: weisshorn
# unknown word: jaiyen
# unknown word: volapük
# unknown word: fernleigh
# unknown word: delinquints
# unknown word: sociopathy
# unknown word: ”
# unknown word: botoşani
# unknown word: 1–3
# unknown word: 12–13
# unknown word: /u:/
# unknown word: vrilissia
# unknown word: zeiton-7
# unknown word: varos
# unknown word: abilityhe
# unknown word: un"affected
# unknown word: subcluster
# unknown word: £
# unknown word: hundi
# unknown word: loomine
# unknown word: ’s
# unknown word: barsanti
# unknown word: wulfric
# unknown word: æthelred
# unknown word: agatean
# unknown word: pearwood
# unknown word: graining
# unknown word: mollifying
# unknown word: ’s
# unknown word: bissi
# unknown word: a169
# unknown word: 11½
# unknown word: 6,290
# unknown word: freckling
# unknown word: j.j.school
# unknown word: parabats
# unknown word: dirda
# unknown word: hwt
# unknown word: range.01–.5
# unknown word: mid-1696
# unknown word: microfibers
# unknown word: posthoumously
# unknown word: —
# unknown word: —
# unknown word: wittayanusorn
# unknown word: –
# unknown word: heldenleben
# unknown word: —
# unknown word: —
# unknown word: perfectionists
# unknown word: opisthoproctid
# unknown word: reiher
# unknown word: lvs
# unknown word: roškovs
# unknown word: colubrids
# unknown word: copaia
# unknown word: copaia
# unknown word: roadrailer
# unknown word: guenièvre
# unknown word: serba
# unknown word: åkerfeldt
# unknown word: carbcn
# unknown word: neibour
# unknown word: shekpura
# unknown word: −14
# unknown word: °c
# unknown word: −20
# unknown word: °c
# unknown word: …
# unknown word: supersub
# unknown word: neuadd
# unknown word: overslept
# unknown word: crowed
# unknown word: urnerboden
# unknown word: 10–20
# unknown word: choub
# unknown word: ’s
# unknown word: “
# unknown word: ”
# unknown word: evelington
# unknown word: misplacement
# unknown word: dumosa
# unknown word: cockers
# unknown word: doff
# unknown word: quazal
# unknown word: quetzalcóatl
# unknown word: rainless
# unknown word: jpra
# unknown word: masataka
# unknown word: d15s
# unknown word: t14
# unknown word: aremberg
# unknown word: s.4
# unknown word: 7½
# unknown word: hd62166
# unknown word: viaţa
# unknown word: românească
# unknown word: adevărul
# unknown word: sămănătorul
# unknown word: ’s
# unknown word: cadsam
# unknown word: kids-
# unknown word: eliding
# unknown word: schlusnus
# unknown word: domgraf
# unknown word: fassbaender
# unknown word: hüsch
# unknown word: £
# unknown word: rhiani
# unknown word: ’s
# unknown word: pienso
# unknown word: hengeveld
# unknown word: hunfrid
# unknown word: ansgot
# unknown word: yukichi
# unknown word: kanrin
# unknown word: montelupo
# unknown word: bojer
# unknown word: postgres95
# unknown word: felipillo
# unknown word: djimon
# unknown word: hounsou
# unknown word: zuwanie
# unknown word: 1720–1772
# unknown word: sattelihu
# unknown word: eghnisara
# unknown word: métis
# unknown word: chip-48
# unknown word: chip-8
# unknown word: díaz
# unknown word: juárez
# unknown word: 3-lisp
# unknown word: builtin
# unknown word: autshumato
# unknown word: kleutgen
# unknown word: —
# unknown word: disjointedly
# unknown word: ilanga
# unknown word: benen
# unknown word: fé
# unknown word: ponselle
# unknown word: harthan
# unknown word: barthélemy
# unknown word: alençon
# unknown word: calambu
# unknown word: limasawa
# unknown word: psyco
# unknown word: pypy
# unknown word: psyco
# unknown word: basicode
# unknown word: bascoder
# unknown word: basicode
# unknown word: ewondo
# unknown word: gcad3d
# unknown word: sablevm
# unknown word: uiterwyk
# unknown word: wordprocessor
# unknown word: issi
# unknown word: aqabya
# unknown word: aqabya
# unknown word: meturgeman
# unknown word: sheren
# unknown word: 舌人
# unknown word: monacans
# unknown word: haner
# unknown word: jruby
# unknown word: jitted
# unknown word: “
# unknown word: ”
# unknown word: multitasker
# unknown word: todays
# unknown word: domov
# unknown word: můj
# unknown word: hessling
# unknown word: pcboard
# unknown word: furtwängler
# unknown word: ywait
# unknown word: yoix
# unknown word: peoples’
# unknown word: roudakoff
# unknown word: ’s
# unknown word: abbahu
# unknown word: sotah
# unknown word: 40a
# unknown word: yousry
# unknown word: romica
# unknown word: puceanu
# unknown word: (;
# unknown word: qiting
# unknown word: lagrené
# unknown word: callery
# unknown word: bolcoff
# unknown word: solá
# unknown word: chutzpis
# unknown word: shamua
# unknown word: hakinai
# unknown word: yesheivav
# unknown word: damah
# unknown word: tangomarkkinat
# unknown word: taren
# unknown word: macro-10
# unknown word: skandha
# unknown word: kiakta
# unknown word: flacci
# unknown word: troucillus
# unknown word: metapost
# unknown word: metapost
# unknown word: despradelles
# unknown word: margelov
# unknown word: ruhi
# unknown word: jamelão
# unknown word: mangueira
# unknown word: cadds-2/vlsi
# unknown word: icpl
# unknown word: cmd2
# unknown word: bahá'í
# unknown word: kohlbecker
# unknown word: duml
# unknown word: cortés
# unknown word: tecuichpo
# unknown word: elpidia
# unknown word: frowin
# unknown word: bellevaux
# unknown word: modula-3
# unknown word: obliq
# unknown word: modula-3
# unknown word: tisquantum
# unknown word: fpp-8
# unknown word: fpp-8
# unknown word: oruzgan
# unknown word: participed
# unknown word: slovinskoga
# unknown word: iesika
# unknown word: ’s
# unknown word: מתרגם
# unknown word: metargem
# unknown word: מתורגמן
# unknown word: meturgeman
# unknown word: 1877–1937
# unknown word: resnikoff
# unknown word: pedris
# unknown word: pedris
# unknown word: shinlaies
# unknown word: bandaranike
# unknown word: kapasi
# unknown word: ’s
# unknown word: smartbasic
# unknown word: shinozaki
# unknown word: …
# unknown word: riply
# unknown word: —
# unknown word: ’s
# unknown word: naksau
# unknown word: kullia
# unknown word: unfriendliness
# unknown word: command.com
# unknown word: –
# unknown word: –
# unknown word: gutean
# unknown word: omai
# unknown word: repl
# unknown word: gillikin
# unknown word: ozites
# unknown word: jellia
# unknown word: lispme
# unknown word: sos.kernel
# unknown word: sos.interp
# unknown word: sos.driver
# unknown word: ghostscript
# unknown word: 6502-based
# unknown word: clah
# unknown word: fieldworker
# unknown word: babbini
# unknown word: «
# unknown word: peoples’
# unknown word: heroes’
# unknown word: »
# unknown word: première
# unknown word: ’s
# unknown word: oriazi
# unknown word: «
# unknown word: »
# unknown word: ”
# unknown word: shadia
# unknown word: dissembling
# unknown word: —and
# unknown word: pisek
# unknown word: otakar
# unknown word: ševčík
# unknown word: sevcik
# unknown word: francisc
# unknown word: dvorsák
# unknown word: chelomei
# unknown word: injusticiable
# unknown word: electroacoustics
# unknown word: esl-63
# unknown word: whc
# unknown word: estéfano
# unknown word: thalía
# unknown word: thalía
# unknown word: putschist
# unknown word: jouhaud
# unknown word: chundur
# unknown word: josé
# unknown word: maría
# unknown word: ’s
# unknown word: ’s
# unknown word: ’s
# unknown word: offriends
# unknown word: vilaine
# unknown word: 41%
# unknown word: elxsi
# unknown word: figan
# unknown word: bobek
# unknown word: absacal
# unknown word: 7.24
# unknown word: faygate
# unknown word: standford
# unknown word: ln.40
# unknown word: ln.140
# unknown word: 7%
# unknown word: 12%
# unknown word: floquet
# unknown word: obediencia
# unknown word: debida
# unknown word: pisidian
# unknown word: agbioforum
# unknown word: smallhold
# unknown word: françois
# unknown word: greuze
# unknown word: moët
# unknown word: moët
# unknown word: isabey
# unknown word: compaoré
# unknown word: £
# unknown word: 33%
# unknown word: 23%
# unknown word: kraków
# unknown word: nancarrow
# unknown word: ’s
# unknown word: matalin
# unknown word: –
# unknown word: wqad
# unknown word: wflx
# unknown word: kshb
# unknown word: crise
# unknown word: —
# unknown word: winr
# unknown word: tagesschau
# unknown word: wctc
# unknown word: devu
# unknown word: sarasu
# unknown word: wemt
# unknown word: wcyb
# unknown word: wfxg
# unknown word: wapner
# unknown word: centanni
# unknown word: fnn
# unknown word: corespondent
# unknown word: hankies
# unknown word: outpourings
# unknown word: ’s
# unknown word: erbakan
# unknown word: susurluk
# unknown word: collarless
# unknown word: outgrossing
# unknown word: braviseamo
# unknown word: 0030
# unknown word: wraz
# unknown word: magraoillaigh
# unknown word: wnlo
# unknown word: haussegger
# unknown word: teilifís
# unknown word: 65%
# unknown word: 20.6°c
# unknown word: 69°f
# unknown word: 10.7°c
# unknown word: 51°f
# unknown word: absolutearts
# unknown word: autosuggestion
# unknown word: kkmonroe
# unknown word: stakeouts
# unknown word: 1984/1985
# unknown word: 35mm-70
# unknown word: brightlines
# unknown word: actuates
# unknown word: d2h
# unknown word: d2hs
# unknown word: d2x
# unknown word: d2xs
# unknown word: mpx
# unknown word: servomechanism
# unknown word: safox
# unknown word: viii+
# unknown word: nikkors
# unknown word: al-1
# unknown word: 3.2-inch
# unknown word: 300v
# unknown word: 24x36
# unknown word: rokkor
# unknown word: elph
# unknown word: elph
# unknown word: n2000
# unknown word: f-301
# unknown word: n2020
# unknown word: f-501
# unknown word: maxxum
# unknown word: dynax
# unknown word: panoman
# unknown word: eyestart
# unknown word: tokina
# unknown word: screwdrive
# unknown word: f-501
# unknown word: dimage
# unknown word: dimage
# unknown word: a200
# unknown word: 50d
# unknown word: liveview
# unknown word: t650
# unknown word: w800
# unknown word: w700
# unknown word: maxxum
# unknown word: f1.7
# unknown word: f401
# unknown word: n4004
# unknown word: af35ml
# unknown word: teleconverter
# unknown word: f60
# unknown word: f65
# unknown word: α
# unknown word: pentamirror
# unknown word: ’s
# unknown word: 3mp
# run model for sent len 18
# unknown word: minidv
# unknown word: f80
# unknown word: n80
# unknown word: f-801
# unknown word: f-801s
# unknown word: n8008s.
# unknown word: t80
# unknown word: 3-element
# unknown word: z5fd
# unknown word: –
# unknown word: maxxum
# unknown word: dynax
# unknown word: photographyblog
# unknown word: “
# unknown word: ”
# unknown word: α
# unknown word: retronym
# unknown word: f601
# unknown word: 1/2000
# unknown word: f90
# unknown word: 5000i
# unknown word: maxxum
# unknown word: 5000i
# unknown word: dynax
# unknown word: 5000i
# unknown word: α-5700i
# unknown word: 3000i
# unknown word: 7000i
# unknown word: safox
# unknown word: f3af
# unknown word: maxxums
# unknown word: 20×
# unknown word: 352×288
# unknown word: eos-3
# unknown word: 45-point
# unknown word: eos-1v
# unknown word: eos-1d
# unknown word: d2x
# unknown word: -1ev
# unknown word: 19ev
# unknown word: autoexposure
# unknown word: d40x
# unknown word: d60
# unknown word: d3000
# unknown word: d5000
# unknown word: 30d
# unknown word: 20d
# run model for sent len 21
# unknown word: ce-5
# unknown word: dynax
# unknown word: maxxum
# unknown word: f60
# unknown word: dynax
# unknown word: 800si
# unknown word: 50e
# unknown word: 3-zone
# run model for sent len 26
# unknown word: unlink
# unknown word: elph
# unknown word: ixy
# unknown word: ixus
# unknown word: elph
# unknown word: f/6.7
# unknown word: kenko
# unknown word: teleconverters
# unknown word: f/5.6
# unknown word: f/8
# unknown word: autoexposure
# unknown word: autoexposure
# unknown word: —
# unknown word: —
# unknown word: pentamirror
# unknown word: f-601
# unknown word: f-601
# unknown word: maxxum
# unknown word: 1/8000
# unknown word: 14-segment
# unknown word: microprism
# unknown word: 3.2mp
# unknown word: 6×6
# unknown word: 6×4.5
# unknown word: 1.2l
# unknown word: 1.2l
# unknown word: al-1
# unknown word: 2×
# run model for sent len 24
# unknown word: autoexposure
# unknown word: maxxum
# unknown word: dynax
# unknown word: f50
# unknown word: geartrain
# unknown word: ⅱ
# unknown word: wvga
# unknown word: 854×480
# unknown word: 3.2-megapixel
# unknown word: maxxum
# unknown word: dynax
# unknown word: d200
# unknown word: enlargers
# unknown word: enlargers
# unknown word: mirrorbox
# unknown word: teleconverters
# unknown word: dynax
# unknown word: maxxum
# unknown word: f2.8
# unknown word: ka2
# unknown word: f-801/s
# unknown word: f90/x
# unknown word: tokina
# unknown word: teleconverters
# unknown word: 102400
# unknown word: 35mm-70
# run model for sent len 20
# unknown word: t80
# unknown word: al-1
# unknown word: f601
# unknown word: 35-to-70
# unknown word: stepless
# unknown word: autoexposure
# unknown word: t90
# unknown word: d300
# unknown word: autoexposure
# unknown word: ae-1
# unknown word: t50
# unknown word: fujica
# unknown word: ax-5
# unknown word: fp-1
# unknown word: x-700
# unknown word: a3000
# unknown word: cp-5
# unknown word: t70
# unknown word: om-2s
# unknown word: 159mm
# unknown word: yashica
# unknown word: fx-103
# unknown word: “
# unknown word: ”
# unknown word: photokina
# unknown word: onestep
# unknown word: yashica
# unknown word: s76
# unknown word: sr44
# unknown word: 3.2mp
# unknown word: f-301
# unknown word: f501
# unknown word: n2020
# unknown word: tsaruk
# unknown word: khmeliv
# unknown word: 15%
# unknown word: burdei
# unknown word: podlachia
# unknown word: khakhlak
# unknown word: chachlak
# unknown word: khakhol
# unknown word: khokhol
# unknown word: kotliarevsky
# unknown word: eneida
# unknown word: zahajkiewicz
# unknown word: dymitr
# unknown word: ladyka
# unknown word: pogoń
# unknown word: 10,237
# unknown word: 69.3%
# unknown word: 19.8%
# unknown word: 4.6%
# unknown word: 1.8%
# unknown word: 1.7%
# unknown word: 1.5%
# unknown word: 1.3%
# run model for sent len 32
# unknown word: 46.06%
# unknown word: 32.54%
# unknown word: 15.03%
# unknown word: 4.90%
# run model for sent len 23
# unknown word: przemyśl
# unknown word: makhmoud
# unknown word: esambayev
# unknown word: ukranians
# unknown word: 65%
# unknown word: 22%
# unknown word: yuschenko
# unknown word: 94.6%
# unknown word: 5.8%
# unknown word: 7.7%
# unknown word: 2.3%
# unknown word: 8.7%
# unknown word: 14.4%
# unknown word: 93.7%
# unknown word: 1.4%
# unknown word: 0,5%
# unknown word: 0,2%
# unknown word: 0,4%
# unknown word: 0,5%
# unknown word: ationalities
# unknown word: szepes
# unknown word: 50.4%
# unknown word: 58.2%
# unknown word: 58%
# unknown word: 35%
# unknown word: 25%
# unknown word: 25%
# unknown word: 13.8%
# unknown word: 8.4%
# unknown word: 8%
# unknown word: 0.7%
# unknown word: 6%
# unknown word: 6%
# unknown word: chornovil
# unknown word: kraków
# unknown word: 1,572
# unknown word: josephburgh
# unknown word: ukrainophiles
# unknown word: maramureş
# unknown word: 34,027
# unknown word: 6.67%
# unknown word: oankali
# unknown word: xenogenesis
# unknown word: fostro
# unknown word: lyneea
# unknown word: 2940252203
# unknown word: vorilhon
# unknown word: lassolas
# unknown word: beamships
# unknown word: plejaren
# unknown word: mahalik
# unknown word: "--
# unknown word: monetre
# unknown word: exopolitical
# run model for sent len 27
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-acf7d928d3ee> in <module>()
#      14                 #read in one line at once and batch sentences
#      15                 w_lst=line.strip().split()
# ---> 16                 bg.process_batch(w_lst) # process batch and write to h5py
#      17                 index_in_h5py=bg.same_len_2_index[len(w_lst)]
#      18                 index_out[name].append(str(len(w_lst))+','+str(index_in_h5py))
#
# <ipython-input-11-bcbea514dd0e> in process_batch(self, w_lst)
#      20             print ('run model for sent len {0}'.format(str(sent_len)))
#      21             self.model.reset_state()
# ---> 22             sent_ys = self.model._contexts_rep(xp.array(self.same_len_dict[sent_len]))
#      23             sent_ys=xp.array([arr.data for arr in sent_ys]).swapaxes(0,1)
#      24             #write to h5py
#
# /usr/local/lib/python2.7/dist-packages/context2vec/common/context_models.pyc in _contexts_rep(self, sent_arr)
#     169                 h = self.r2l_1(F.dropout(e, ratio=self.drop_ratio))
#     170             else:
# --> 171                 h = self.r2l_1(e)
#     172             r2l_sent_h.append(h)
#     173
#
# /usr/local/lib/python2.7/dist-packages/chainer/links/connection/lstm.pyc in __call__(self, x)
#     322                 lstm_in += self.lateral(h_update)
#     323             else:
# --> 324                 lstm_in += self.lateral(self.h)
#     325         if self.c is None:
#     326             xp = self.xp
#
# /usr/local/lib/python2.7/dist-packages/chainer/links/connection/linear.pyc in __call__(self, x)
#     127             in_size = functools.reduce(operator.mul, x.shape[1:], 1)
#     128             self._initialize_params(in_size)
# --> 129         return linear.linear(x, self.W, self.b)
#
# /usr/local/lib/python2.7/dist-packages/chainer/functions/connection/linear.pyc in linear(x, W, b)
#     232         args = x, W, b
#     233
# --> 234     y, = LinearFunction().apply(args)
#     235     return y
#
# /usr/local/lib/python2.7/dist-packages/chainer/function_node.pyc in apply(self, inputs)
#     256             self._input_indexes_to_retain = None
#     257             self._output_indexes_to_retain = None
# --> 258             outputs = self.forward(in_data)
#     259
#     260         # Check for output array types
#
# /usr/local/lib/python2.7/dist-packages/chainer/functions/connection/linear.pyc in forward(self, inputs)
#      52             x = numpy.ascontiguousarray(x)
#      53
# ---> 54         y = x.dot(W.T).astype(x.dtype, copy=False)
#      55         if b is not None:
#      56             y += b
#
# KeyboardInterrupt:
